# %% [markdown]
# # Hey CIBC! I'm [Simon Roberts](https://www.linkedin.com/in/simonnroberts/), your next SWAT Consultant

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# I'm a third year [business and computer science student](https://simonneilroberts.medium.com/an-insiders-look-at-the-bucs-program-65db1b165cab) at UBC and I love solving complex problems on teams, especially with technology.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
e = {'Industry' : ['Financial Services', 'Agriculture-Technology', 'Consumer Goods', 'Automotive', 'Telecommunications', 'Non-Profit', 'Higher Education'], 'Hours of Experience': [650, 450, 400, 300, 400, 500, 80]}
df = pd.DataFrame(data=e)
ax = df.plot(kind='bar', title='I have experience in a breadth of industries...', x='Industry', color='#9d2235')
